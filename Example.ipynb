# %% [markdown]
# ##### Parametros:
# - prbs_taps: Taps for the prbs poly as a list. For example: PRBS3=[3,2]
# - paralellism: Number of bits per sample.
# - seed_taps: Taps that define the seed for the PRBS. the length should be equal to the degree of the PRBS meaning that the MSB should be in index 2, for example, for PRBS3: seed_taps = [2,0]

# %%
from prbs import PRBS

prbs_taps = [3,2]
seed_taps = [2,0] # or [2], [2,1] , [2,1,0]. No other options
parallelism = 3
prbs = PRBS.create(prbs_taps,parallelism,seed_taps)

# %%
#Single sample per run
print(prbs.get_sample())
# Out:
# [1, 0, 1]

# %%
#Multiple samples per run
sequence = [prbs.get_sample() for _ in range(10)]
print(sequence)
# Out:
# [[1, 1, 0], [0, 1, 0], [1, 1, 1], [0, 0, 1], [0, 1, 1], [1, 0, 0], [1, 0, 1], [1, 1, 0], [0, 1, 0], [1, 1, 1]]

# %% [markdown]
# ### Next line generates the Def file for the RTL design

# %%
prbs.write_define_file()
prbs.write_vector_file()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 prbs.write_define_file()
# ----> 2 prbs.write_vector_file()
#
# File c:\Users\MarianoCarcamo\OneDrive - Celero Communications Inc\Documentos\MaestriaFulgor\PRBS\prbs.py:58, in PRBS.write_vector_file(self, length)
#      56 sample = self.__sample_generator()
#      57 sequence = [next(sample) for _ in range(length)]
# ---> 58 with open('./vector_files/prbs_vector.out', 'w') as f:
#      59     for i in range(length):
#      60         for j in range(self.__k):
#
# FileNotFoundError: [Errno 2] No such file or directory: './vector_files/prbs_vector.out'
